# %%
# !pip install torch matplotlib numpy scipy scikit-learn transformers datasets evaluate codecarbon
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.14.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.3)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting codecarbon
#   Downloading codecarbon-2.8.3-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Collecting arrow (from codecarbon)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from codecarbon) (8.1.8)
# Collecting fief-client[cli] (from codecarbon)
#   Downloading fief_client-0.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.21.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from codecarbon) (12.0.0)
# Collecting questionary (from codecarbon)
#   Downloading questionary-2.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting rapidfuzz (from codecarbon)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from codecarbon) (13.9.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Collecting httpx<0.28.0,>=0.21.3 (from fief-client[cli]->codecarbon)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jwcrypto<2.0.0,>=1.4 (from fief-client[cli]->codecarbon)
#   Downloading jwcrypto-1.5.6-py3-none-any.whl.metadata (3.1 kB)
# Collecting yaspin (from fief-client[cli]->codecarbon)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->codecarbon) (12.570.86)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from questionary->codecarbon) (3.0.50)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (2.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.14.0)
# Requirement already satisfied: cryptography>=3.4 in /usr/local/lib/python3.11/dist-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->fief-client[cli]->codecarbon)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 21.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.8 MB/s eta 0:00:00
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 33.5 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.3 MB/s eta 0:00:00
# Downloading codecarbon-2.8.3-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.7/516.7 kB 33.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.5 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 14.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.2 MB/s eta 0:00:00
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.0 MB/s eta 0:00:00
# Downloading questionary-2.1.0-py3-none-any.whl (36 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.0 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.0 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.8 MB/s eta 0:00:00
# Downloading jwcrypto-1.5.6-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 8.0 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Downloading fief_client-0.20.0-py3-none-any.whl (20 kB)
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: xxhash, types-python-dateutil, termcolor, rapidfuzz, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, dill, yaspin, questionary, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, httpx, arrow, nvidia-cusolver-cu12, jwcrypto, fief-client, datasets, evaluate, codecarbon
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.0.1
#     Uninstalling termcolor-3.0.1:
#       Successfully uninstalled termcolor-3.0.1
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.9.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed arrow-1.3.0 codecarbon-2.8.3 datasets-3.5.0 dill-0.3.8 evaluate-0.4.3 fief-client-0.20.0 fsspec-2024.12.0 httpx-0.27.2 jwcrypto-1.5.6 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 questionary-2.1.0 rapidfuzz-3.13.0 termcolor-2.3.0 types-python-dateutil-2.9.0.20241206 xxhash-3.5.0 yaspin-3.1.0

# %%
import torch
import pandas as pd
from datasets import load_dataset, DatasetDict
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from datasets import DatasetDict
from peft import get_peft_model, LoraConfig, TaskType
from transformers import TrainerCallback
import time
import matplotlib.pyplot as plt
from codecarbon import EmissionsTracker
from transformers import AutoTokenizer, DistilBertForSequenceClassification

# %%
# Inspecte les étiquettes du dataset
from datasets import load_dataset

# Charger le dataset
dataset = load_dataset("hate_speech18")

# Vérifie les étiquettes dans le dataset d'entraînement
print(dataset['train'].features['label'])
# Out:
# ClassLabel(names=['noHate', 'hate', 'idk/skip', 'relation'], id=None)

# %%
# Séparer en train et test
split_datasets = dataset["train"].train_test_split(test_size=0.2)

datasets = DatasetDict({
    "train": split_datasets["train"],
    "test": split_datasets["test"],
})

# Préparer le tokenizer
tokenizer = AutoTokenizer.from_pretrained("answerdotai/ModernBERT-base")

def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=512)

# Appliquer la tokenization
tokenized_datasets = datasets.map(tokenize_function, batched=True)

# Charger le modèle pré-entraîné sans fine-tuning
base_model = DistilBertForSequenceClassification.from_pretrained("answerdotai/ModernBERT-base", num_labels=4)
# Out:
# Map:   0%|          | 0/8755 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2189 [00:00<?, ? examples/s]
# You are using a model of type modernbert to instantiate a model of type distilbert. This is not supported for all configurations of models and can yield errors.
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at answerdotai/ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'distilbert.embeddings.LayerNorm.bias', 'distilbert.embeddings.LayerNorm.weight', 'distilbert.embeddings.position_embeddings.weight', 'distilbert.embeddings.word_embeddings.weight', 'distilbert.transformer.layer.0.attention.k_lin.bias', 'distilbert.transformer.layer.0.attention.k_lin.weight', 'distilbert.transformer.layer.0.attention.out_lin.bias', 'distilbert.transformer.layer.0.attention.out_lin.weight', 'distilbert.transformer.layer.0.attention.q_lin.bias', 'distilbert.transformer.layer.0.attention.q_lin.weight', 'distilbert.transformer.layer.0.attention.v_lin.bias', 'distilbert.transformer.layer.0.attention.v_lin.weight', 'distilbert.transformer.layer.0.ffn.lin1.bias', 'distilbert.transformer.layer.0.ffn.lin1.weight', 'distilbert.transformer.layer.0.ffn.lin2.bias', 'distilbert.transformer.layer.0.ffn.lin2.weight', 'distilbert.transformer.layer.0.output_layer_norm.bias', 'distilbert.transformer.layer.0.output_layer_norm.weight', 'distilbert.transformer.layer.0.sa_layer_norm.bias', 'distilbert.transformer.layer.0.sa_layer_norm.weight', 'distilbert.transformer.layer.1.attention.k_lin.bias', 'distilbert.transformer.layer.1.attention.k_lin.weight', 'distilbert.transformer.layer.1.attention.out_lin.bias', 'distilbert.transformer.layer.1.attention.out_lin.weight', 'distilbert.transformer.layer.1.attention.q_lin.bias', 'distilbert.transformer.layer.1.attention.q_lin.weight', 'distilbert.transformer.layer.1.attention.v_lin.bias', 'distilbert.transformer.layer.1.attention.v_lin.weight', 'distilbert.transformer.layer.1.ffn.lin1.bias', 'distilbert.transformer.layer.1.ffn.lin1.weight', 'distilbert.transformer.layer.1.ffn.lin2.bias', 'distilbert.transformer.layer.1.ffn.lin2.weight', 'distilbert.transformer.layer.1.output_layer_norm.bias', 'distilbert.transformer.layer.1.output_layer_norm.weight', 'distilbert.transformer.layer.1.sa_layer_norm.bias', 'distilbert.transformer.layer.1.sa_layer_norm.weight', 'distilbert.transformer.layer.10.attention.k_lin.bias', 'distilbert.transformer.layer.10.attention.k_lin.weight', 'distilbert.transformer.layer.10.attention.out_lin.bias', 'distilbert.transformer.layer.10.attention.out_lin.weight', 'distilbert.transformer.layer.10.attention.q_lin.bias', 'distilbert.transformer.layer.10.attention.q_lin.weight', 'distilbert.transformer.layer.10.attention.v_lin.bias', 'distilbert.transformer.layer.10.attention.v_lin.weight', 'distilbert.transformer.layer.10.ffn.lin1.bias', 'distilbert.transformer.layer.10.ffn.lin1.weight', 'distilbert.transformer.layer.10.ffn.lin2.bias', 'distilbert.transformer.layer.10.ffn.lin2.weight', 'distilbert.transformer.layer.10.output_layer_norm.bias', 'distilbert.transformer.layer.10.output_layer_norm.weight', 'distilbert.transformer.layer.10.sa_layer_norm.bias', 'distilbert.transformer.layer.10.sa_layer_norm.weight', 'distilbert.transformer.layer.11.attention.k_lin.bias', 'distilbert.transformer.layer.11.attention.k_lin.weight', 'distilbert.transformer.layer.11.attention.out_lin.bias', 'distilbert.transformer.layer.11.attention.out_lin.weight', 'distilbert.transformer.layer.11.attention.q_lin.bias', 'distilbert.transformer.layer.11.attention.q_lin.weight', 'distilbert.transformer.layer.11.attention.v_lin.bias', 'distilbert.transformer.layer.11.attention.v_lin.weight', 'distilbert.transformer.layer.11.ffn.lin1.bias', 'distilbert.transformer.layer.11.ffn.lin1.weight', 'distilbert.transformer.layer.11.ffn.lin2.bias', 'distilbert.transformer.layer.11.ffn.lin2.weight', 'distilbert.transformer.layer.11.output_layer_norm.bias', 'distilbert.transformer.layer.11.output_layer_norm.weight', 'distilbert.transformer.layer.11.sa_layer_norm.bias', 'distilbert.transformer.layer.11.sa_layer_norm.weight', 'distilbert.transformer.layer.12.attention.k_lin.bias', 'distilbert.transformer.layer.12.attention.k ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# **FINETUNING AVEC LoRa**

# %%
# Récupérer les noms des classes directement à partir du dataset
class_names = dataset['train'].features['label'].names

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = torch.argmax(torch.tensor(logits), dim=-1)

    accuracy = accuracy_score(labels, predictions)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average=None, zero_division=1)

    # Calcul des métriques globales (moyenne des classes)
    precision_global = precision.mean()
    recall_global = recall.mean()
    f1_macro = f1.mean()  # Ajout du F1-score macro

    metrics = {
        "accuracy": accuracy,
        "precision_global": precision_global,
        "recall_global": recall_global,
        "f1_macro": f1_macro
    }

    # Ajouter les métriques par classe avec les noms explicites
    for i, (p, r, f) in enumerate(zip(precision, recall, f1)):
        metrics[f"precision_{class_names[i]}"] = p
        metrics[f"recall_{class_names[i]}"] = r
        metrics[f"f1_{class_names[i]}"] = f

    return metrics

# Configurer LoRA
lora_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,  # Classification de séquence
    r=8,  # Rang de la décomposition
    lora_alpha=16,  # Facteur d'adaptation
    lora_dropout=0.1,  # Dropout pour LoRA
    target_modules=["q_lin", "v_lin"]  # Modules spécifiques à LoRA dans les transformers
)

# Appliquer LoRA au modèle
model = get_peft_model(base_model, lora_config)
model.print_trainable_parameters()

# Configurer l'entraînement avec fine-tuning LoRA
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",  # Évaluation à chaque époque
    save_strategy="epoch",  # Sauvegarde à chaque époque
    logging_strategy="steps",  # Log les métriques à chaque `logging_steps`
    logging_steps=10,  # Enregistre la loss toutes les 10 étapes
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    report_to="wandb",
    overwrite_output_dir=True,
    disable_tqdm=False
)

small_train_dataset = tokenized_datasets["train"]
small_test_dataset = tokenized_datasets["test"]

# Initialisation du Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train_dataset,  # Dataset d'entraînement
    eval_dataset=small_test_dataset,  # Dataset de test
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

tracker = EmissionsTracker()
tracker.start()

train_result = trainer.train()

emissions = tracker.stop()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1611: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-5-2cf6649f42b2>:64: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# trainable params: 1,134,340 || all params: 202,636,808 || trainable%: 0.5598
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# [codecarbon INFO @ 09:07:48] [setup] RAM Tracking...
# [codecarbon INFO @ 09:07:48] [setup] CPU Tracking...
# [codecarbon WARNING @ 09:07:48] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 09:07:49] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 09:07:49] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 09:07:49] [setup] GPU Tracking...
# [codecarbon INFO @ 09:07:49] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 09:07:49] >>> Tracker's metadata:
# [codecarbon INFO @ 09:07:49]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 09:07:49]   Python version: 3.11.12
# [codecarbon INFO @ 09:07:49]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 09:07:49]   Available RAM : 12.675 GB
# [codecarbon INFO @ 09:07:49]   CPU count: 2
# [codecarbon INFO @ 09:07:49]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 09:07:49]   GPU count: 1
# [codecarbon INFO @ 09:07:49]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 09:07:49] Saving emissions data to file /content/emissions.csv
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: alex-lochain (alex-lochain-le-mans-universit-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/content/wandb/run-20250411_090750-k7a5s78m</code>
# Syncing run <strong><a href='https://wandb.ai/alex-lochain-le-mans-universit-/huggingface/runs/k7a5s78m' target="_blank">./results</a></strong> to <a href='https://wandb.ai/alex-lochain-le-mans-universit-/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alex-lochain-le-mans-universit-/huggingface' target="_blank">https://wandb.ai/alex-lochain-le-mans-universit-/huggingface</a>
#  View run at <a href='https://wandb.ai/alex-lochain-le-mans-universit-/huggingface/runs/k7a5s78m' target="_blank">https://wandb.ai/alex-lochain-le-mans-universit-/huggingface/runs/k7a5s78m</a>
#     <div>
#
#       <progress value='3285' max='3285' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3285/3285 57:30, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision Global</th>
#       <th>Recall Global</th>
#       <th>F1 Macro</th>
#       <th>Precision Nohate</th>
#       <th>Recall Nohate</th>
#       <th>F1 Nohate</th>
#       <th>Precision Hate</th>
#       <th>Recall Hate</th>
#       <th>F1 Hate</th>
#       <th>Precision Idk/skip</th>
#       <th>Recall Idk/skip</th>
#       <th>F1 Idk/skip</th>
#       <th>Precision Relation</th>
#       <th>Recall Relation</th>
#       <th>F1 Relation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.665200</td>
#       <td>0.458668</td>
#       <td>0.859753</td>
#       <td>0.964938</td>
#       <td>0.250000</td>
#       <td>0.231147</td>
#       <td>0.859753</td>
#       <td>1.000000</td>
#       <td>0.924589</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.499800</td>
#       <td>0.449403</td>
#       <td>0.859753</td>
#       <td>0.798452</td>
#       <td>0.250844</td>
#       <td>0.233125</td>
#       <td>0.860476</td>
#       <td>0.999469</td>
#       <td>0.924779</td>
#       <td>0.333333</td>
#       <td>0.003906</td>
#       <td>0.007722</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.421000</td>
#       <td>0.478370</td>
#       <td>0.859753</td>
#       <td>0.964938</td>
#       <td>0.250000</td>
#       <td>0.231147</td>
#       <td>0.859753</td>
#       <td>1.000000</td>
#       <td>0.924589</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# [codecarbon INFO @ 09:08:04] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:08:04] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:08:04] Energy consumed for all GPUs : 0.000257 kWh. Total GPU Power : 61.642852282613916 W
# [codecarbon INFO @ 09:08:04] 0.000454 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:08:19] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:08:19] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:08:19] Energy consumed for all GPUs : 0.000546 kWh. Total GPU Power : 69.4313000927635 W
# [codecarbon INFO @ 09:08:19] 0.000940 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:08:34] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:08:34] Energy consumed for all CPUs : 0.000531 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:08:34] Energy consumed for all GPUs : 0.000837 kWh. Total GPU Power : 69.81878093136356 W
# [codecarbon INFO @ 09:08:34] 0.001428 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:08:49] Energy consumed for RAM : 0.000079 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:08:49] Energy consumed for all CPUs : 0.000708 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:08:49] Energy consumed for all GPUs : 0.001125 kWh. Total GPU Power : 69.08513129127734 W
# [codecarbon INFO @ 09:08:49] 0.001913 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:04] Energy consumed for RAM : 0.000099 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:09:04] Energy consumed for all CPUs : 0.000886 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:09:04] Energy consumed for all GPUs : 0.001415 kWh. Total GPU Power : 69.55055523224743 W
# [codecarbon INFO @ 09:09:04] 0.002400 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:19] Energy consumed for RAM : 0.000119 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:09:19] Energy consumed for all CPUs : 0.001062 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:09:19] Energy consumed for all GPUs : 0.001704 kWh. Total GPU Power : 69.37504418716092 W
# [codecarbon INFO @ 09:09:19] 0.002885 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:34] Energy consumed for RAM : 0.000139 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:09:34] Energy consumed for all CPUs : 0.001240 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:09:34] Energy consumed for all GPUs : 0.001990 kWh. Total GPU Power : 68.5433084711324 W
# [codecarbon INFO @ 09:09:34] 0.003368 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:49] Energy consumed for RAM : 0.000158 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:09:49] Energy consumed for all CPUs : 0.001416 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:09:49] Energy consumed for all GPUs : 0.002280 kWh. Total GPU Power : 69.83920867643094 W
# [codecarbon INFO @ 09:09:49] 0.003855 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:49] 0.008593 g.CO2eq/s mean an estimation of 270.99150489021537 kg.CO2eq/year
# [codecarbon INFO @ 09:10:04] Energy consumed for RAM : 0.000178 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:10:04] Energy consumed for all CPUs : 0.001594 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:10:04] Energy consumed for all GPUs : 0.002569 kWh. Total GPU Power : 69.22766379363892 W
# [codecarbon INFO @ 09:10:04] 0.004341 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:10:19] Energy consumed for RAM : 0.000198 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:10:19] Energy consumed for all CPUs : 0.001771 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:10:19] Energy consumed for all GPUs : 0.002858 kWh. Total GPU Power : 69.3397730526437 W
# [codecarbon INFO @ 09:10:19] 0.004826 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:10:34] Energy consumed for RAM : 0.000218 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:10:34] Energy consumed for all CPUs : 0.001948 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:10:34] Energy consumed for all GPUs : 0.003148 kWh. Total GPU Power : 69.7053171768118 W
# [codecarbon INFO @ 09:10:34] 0.005313 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:10:49] Energy consumed for RAM : 0.000238 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:10:49] Energy consumed for all CPUs : 0.002125 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:10:49] Energy consumed for all GPUs : 0.003436 kWh. Total GPU Power : 69.21022664083975 W
# [codecarbon INFO @ 09:10:49] 0.005798 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:04] Energy consumed for RAM : 0.000257 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:11:04] Energy consumed for all CPUs : 0.002302 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:11:04] Energy consumed for all GPUs : 0.003725 kWh. Total GPU Power : 69.40354310147485 W
# [codecarbon INFO @ 09:11:04] 0.006284 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:19] Energy consumed for RAM : 0.000277 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:11:19] Energy consumed for all CPUs : 0.002479 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:11:19] Energy consumed for all GPUs : 0.004016 kWh. Total GPU Power : 69.72818059773192 W
# [codecarbon INFO @ 09:11:19] 0.006772 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:34] Energy consumed for RAM : 0.000297 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:11:34] Energy consumed for all CPUs : 0.002656 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:11:34] Energy consumed for all GPUs : 0.004305 kWh. Total GPU Power : 69.2851430157032 W
# [codecarbon INFO @ 09:11:34] 0.007257 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:49] Energy consumed for RAM : 0.000317 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:11:49] Energy consumed for all CPUs : 0.002833 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:11:49] Energy consumed for all GPUs : 0.004595 kWh. Total GPU Power : 69.72267948017482 W
# [codecarbon INFO @ 09:11:49] 0.007744 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:49] 0.008671 g.CO2eq/s mean an estimation of 273.4476897571675 kg.CO2eq/year
# [codecarbon INFO @ 09:12:04] Energy consumed for RAM : 0.000337 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:12:04] Energy consumed for all CPUs : 0.003010 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:12:04] Energy consumed for all GPUs : 0.004884 kWh. Total GPU Power : 69.30981982586611 W
# [codecarbon INFO @ 09:12:04] 0.008230 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:12:19] Energy consumed for RAM : 0.000356 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:12:19] Energy consumed for all CPUs : 0.003187 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:12:19] Energy consumed for all GPUs : 0.005172 kWh. Total GPU Power : 69.2952430348358 W
# [codecarbon INFO @ 09:12:19] 0.008715 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:12:34] Energy consumed for RAM : 0.000376 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:12:34] Energy consumed for all CPUs : 0.003364 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:12:34] Energy consumed for all GPUs : 0.005461 kWh. Total GPU Power : 69.36633913898807 W
# [codecarbon INFO @ 09:12:34] 0.009201 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:12:49] Energy consumed for RAM : 0.000396 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:12:49] Energy consumed for all CPUs : 0.003541 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:12:49] Energy consumed for all GPUs : 0.005752 kWh. Total GPU Power : 69.81169306492286 W
# [codecarbon INFO @ 09:12:49] 0.009688 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:04] Energy consumed for RAM : 0.000416 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:13:04] Energy consumed for all CPUs : 0.003718 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:13:04] Energy consumed for all GPUs : 0.006040 kWh. Total GPU Power : 69.16445626284538 W
# [codecarbon INFO @ 09:13:04] 0.010174 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:19] Energy consumed for RAM : 0.000435 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:13:19] Energy consumed for all CPUs : 0.003895 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:13:19] Energy consumed for all GPUs : 0.006331 kWh. Total GPU Power : 69.6926136529236 W
# [codecarbon INFO @ 09:13:19] 0.010661 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:34] Energy consumed for RAM : 0.000455 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:13:34] Energy consumed for all CPUs : 0.004072 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:13:34] Energy consumed for all GPUs : 0.006620 kWh. Total GPU Power : 69.39737926872736 W
# [codecarbon INFO @ 09:13:34] 0.011147 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:49] Energy consumed for RAM : 0.000475 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:13:49] Energy consumed for all CPUs : 0.004249 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:13:49] Energy consumed for all GPUs : 0.006908 kWh. Total GPU Power : 69.20807093361319 W
# [codecarbon INFO @ 09:13:49] 0.011632 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:49] 0.008668 g.CO2eq/s mean an estimation of 273.34047857202336 kg.CO2eq/year
# [codecarbon INFO @ 09:14:04] Energy consumed for RAM : 0.000495 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:14:04] Energy consumed for all CPUs : 0.004426 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:14:04] Energy consumed for all GPUs : 0.007199 kWh. Total GPU Power : 69.70799936097987 W
# [codecarbon INFO @ 09:14:04] 0.012120 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:19] Energy consumed for RAM : 0.000515 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:14:19] Energy consumed for all CPUs : 0.004603 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:14:19] Energy consumed for all GPUs : 0.007487 kWh. Total GPU Power : 69.26531663285512 W
# [codecarbon INFO @ 09:14:19] 0.012605 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:34] Energy consumed for RAM : 0.000534 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:14:34] Energy consumed for all CPUs : 0.004780 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:14:34] Energy consumed for all GPUs : 0.007778 kWh. Total GPU Power : 69.73885848672353 W
# [codecarbon INFO @ 09:14:34] 0.013092 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:49] Energy consumed for RAM : 0.000554 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:14:49] Energy consumed for all CPUs : 0.004957 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:14:49] Energy consumed for all GPUs : 0.008067 kWh. Total GPU Power : 69.45747505942379 W
# [codecarbon INFO @ 09:14:49] 0.013578 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:04] Energy consumed for RAM : 0.000574 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:15:04] Energy consumed for all CPUs : 0.005134 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:15:04] Energy consumed for all GPUs : 0.008355 kWh. Total GPU Power : 69.38011073350312 W
# [codecarbon INFO @ 09:15:04] 0.014063 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:19] Energy consumed for RAM : 0.000594 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:15:19] Energy consumed for all CPUs : 0.005311 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:15:19] Energy consumed for all GPUs : 0.008646 kWh. Total GPU Power : 69.7301815686935 W
# [codecarbon INFO @ 09:15:19] 0.014551 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:34] Energy consumed for RAM : 0.000614 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:15:34] Energy consumed for all CPUs : 0.005488 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:15:34] Energy consumed for all GPUs : 0.008935 kWh. Total GPU Power : 69.33268923860203 W
# [codecarbon INFO @ 09:15:34] 0.015037 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:49] Energy consumed for RAM : 0.000633 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:15:49] Energy consumed for all CPUs : 0.005665 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:15:49] Energy consumed for all GPUs : 0.009223 kWh. Total GPU Power : 69.20274217264873 W
# [codecarbon INFO @ 09:15:49] 0.015521 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:49] 0.008671 g.CO2eq/s mean an estimation of 273.44452555023696 kg.CO2eq/year
# [codecarbon INFO @ 09:16:04] Energy consumed for RAM : 0.000653 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:16:04] Energy consumed for all CPUs : 0.005842 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:16:04] Energy consumed for all GPUs : 0.009514 kWh. Total GPU Power : 69.66828903875555 W
# [codecarbon INFO @ 09:16:04] 0.016009 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:16:19] Energy consumed for RAM : 0.000673 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:16:19] Energy consumed for all CPUs : 0.006019 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:16:19] Energy consumed for all GPUs : 0.009802 kWh. Total GPU Power : 69.26231216096912 W
# [codecarbon INFO @ 09:16:19] 0.016494 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:16:34] Energy consumed for RAM : 0.000693 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:16:34] Energy consumed for all CPUs : 0.006196 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:16:34] Energy consumed for all GPUs : 0.010091 kWh. Total GPU Power : 69.34678568450084 W
# [codecarbon INFO @ 09:16:34] 0.016980 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:16:49] Energy consumed for RAM : 0.000713 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:16:49] Energy consumed for all CPUs : 0.006373 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:16:49] Energy consumed for all GPUs : 0.010381 kWh. Total GPU Power : 69.67773381336234 W
# [codecarbon INFO @ 09:16:49] 0.017467 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:04] Energy consumed for RAM : 0.000732 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:17:04] Energy consumed for all CPUs : 0.006550 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:17:04] Energy consumed for all GPUs : 0.010670 kWh. Total GPU Power : 69.3154930362313 W
# [codecarbon INFO @ 09:17:04] 0.017953 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:19] Energy consumed for RAM : 0.000752 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:17:19] Energy consumed for all CPUs : 0.006727 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:17:19] Energy consumed for all GPUs : 0.010961 kWh. Total GPU Power : 69.78325859952913 W
# [codecarbon INFO @ 09:17:19] 0.018440 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:34] Energy consumed for RAM : 0.000772 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:17:34] Energy consumed for all CPUs : 0.006904 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:17:34] Energy consumed for all GPUs : 0.011250 kWh. Total GPU Power : 69.26221956004805 W
# [codecarbon INFO @ 09:17:34] 0.018926 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:49] Energy consumed for RAM : 0.000792 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:17:49] Energy consumed for all CPUs : 0.007081 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:17:49] Energy consumed for all GPUs : 0.011538 kWh. Total GPU Power : 69.24415341476973 W
# [codecarbon INFO @ 09:17:49] 0.019412 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:49] 0.008670 g.CO2eq/s mean an estimation of 273.422451029153 kg.CO2eq/year
# [codecarbon INFO @ 09:18:04] Energy consumed for RAM : 0.000812 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:18:04] Energy consumed for all CPUs : 0.007258 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:18:04] Energy consumed for all GPUs : 0.011829 kWh. Total GPU Power : 69.76642627628775 W
# [codecarbon INFO @ 09:18:04] 0.019899 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:19] Energy consumed for RAM : 0.000831 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:18:19] Energy consumed for all CPUs : 0.007435 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:18:19] Energy consumed for all GPUs : 0.012117 kWh. Total GPU Power : 69.22080677182454 W
# [codecarbon INFO @ 09:18:19] 0.020384 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:34] Energy consumed for RAM : 0.000851 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:18:34] Energy consumed for all CPUs : 0.007613 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:18:34] Energy consumed for all GPUs : 0.012408 kWh. Total GPU Power : 69.73501475236176 W
# [codecarbon INFO @ 09:18:34] 0.020871 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:49] Energy consumed for RAM : 0.000871 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:18:49] Energy consumed for all CPUs : 0.007790 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:18:49] Energy consumed for all GPUs : 0.012697 kWh. Total GPU Power : 69.2902602499062 W
# [codecarbon INFO @ 09:18:49] 0.021357 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:04] Energy consumed for RAM : 0.000891 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:19:04] Energy consumed for all CPUs : 0.007967 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:19:05] Energy consumed for all GPUs : 0.012985 kWh. Total GPU Power : 69.3338128209165 W
# [codecarbon INFO @ 09:19:05] 0.021843 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:19] Energy consumed for RAM : 0.000911 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:19:19] Energy consumed for all CPUs : 0.008144 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:19:20] Energy consumed for all GPUs : 0.013276 kWh. Total GPU Power : 69.73490575094546 W
# [codecarbon INFO @ 09:19:20] 0.022330 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:34] Energy consumed for RAM : 0.000930 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:19:34] Energy consumed for all CPUs : 0.008321 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:19:34] Energy consumed for all GPUs : 0.013564 kWh. Total GPU Power : 69.30404274129624 W
# [codecarbon INFO @ 09:19:35] 0.022815 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:50] Energy consumed for RAM : 0.000950 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:19:50] Energy consumed for all CPUs : 0.008498 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:19:50] Energy consumed for all GPUs : 0.013853 kWh. Total GPU Power : 69.19194181192692 W
# [codecarbon INFO @ 09:19:50] 0.023300 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:50] 0.008671 g.CO2eq/s mean an estimation of 273.4389161292273 kg.CO2eq/year
# [codecarbon INFO @ 09:20:05] Energy consumed for RAM : 0.000970 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:20:05] Energy consumed for all CPUs : 0.008675 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:20:05] Energy consumed for all GPUs : 0.014143 kWh. Total GPU Power : 69.8345186982651 W
# [codecarbon INFO @ 09:20:05] 0.023788 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:20:20] Energy consumed for RAM : 0.000990 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:20:20] Energy consumed for all CPUs : 0.008852 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:20:20] Energy consumed for all GPUs : 0.014432 kWh. Total GPU Power : 69.31865710446277 W
# [codecarbon INFO @ 09:20:20] 0.024273 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:20:35] Energy consumed for RAM : 0.001009 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:20:35] Energy consumed for all CPUs : 0.009029 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:20:35] Energy consumed for all GPUs : 0.014721 kWh. Total GPU Power : 69.27915683231258 W
# [codecarbon INFO @ 09:20:35] 0.024759 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:20:50] Energy consumed for RAM : 0.001029 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:20:50] Energy consumed for all CPUs : 0.009206 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:20:50] Energy consumed for all GPUs : 0.015011 kWh. Total GPU Power : 69.7398472862476 W
# [codecarbon INFO @ 09:20:50] 0.025246 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:05] Energy consumed for RAM : 0.001049 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:21:05] Energy consumed for all CPUs : 0.009383 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:21:05] Energy consumed for all GPUs : 0.015300 kWh. Total GPU Power : 69.3077853263311 W
# [codecarbon INFO @ 09:21:05] 0.025732 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:20] Energy consumed for RAM : 0.001069 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:21:20] Energy consumed for all CPUs : 0.009560 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:21:20] Energy consumed for all GPUs : 0.015589 kWh. Total GPU Power : 69.30577550533609 W
# [codecarbon INFO @ 09:21:20] 0.026217 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:35] Energy consumed for RAM : 0.001089 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:21:35] Energy consumed for all CPUs : 0.009737 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:21:35] Energy consumed for all GPUs : 0.015879 kWh. Total GPU Power : 69.77904484649147 W
# [codecarbon INFO @ 09:21:35] 0.026705 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:50] Energy consumed for RAM : 0.001108 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:21:50] Energy consumed for all CPUs : 0.009914 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:21:50] Energy consumed for all GPUs : 0.016168 kWh. Total GPU Power : 69.2552693916526 W
# [codecarbon INFO @ 09:21:50] 0.027190 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:50] 0.008672 g.CO2eq/s mean an estimation of 273.48072149931187 kg.CO2eq/year
# [codecarbon INFO @ 09:22:05] Energy consumed for RAM : 0.001128 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:22:05] Energy consumed for all CPUs : 0.010091 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:22:05] Energy consumed for all GPUs : 0.016456 kWh. Total GPU Power : 69.29535859625643 W
# [codecarbon INFO @ 09:22:05] 0.027675 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:22:20] Energy consumed for RAM : 0.001148 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:22:20] Energy consumed for all CPUs : 0.010268 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:22:20] Energy consumed for all GPUs : 0.016747 kWh. Total GPU Power : 69.77122141745743 W
# [codecarbon INFO @ 09:22:20] 0.028163 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:22:35] Energy consumed for RAM : 0.001168 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:22:35] Energy consumed for all CPUs : 0.010445 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:22:35] Energy consumed for all GPUs : 0.017036 kWh. Total GPU Power : 69.32619067725841 W
# [codecarbon INFO @ 09:22:35] 0.028648 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:22:50] Energy consumed for RAM : 0.001188 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:22:50] Energy consumed for all CPUs : 0.010622 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:22:50] Energy consumed for all GPUs : 0.017327 kWh. Total GPU Power : 69.75048147652385 W
# [codecarbon INFO @ 09:22:50] 0.029136 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:05] Energy consumed for RAM : 0.001207 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:23:05] Energy consumed for all CPUs : 0.010799 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:23:05] Energy consumed for all GPUs : 0.017615 kWh. Total GPU Power : 69.23086614775653 W
# [codecarbon INFO @ 09:23:05] 0.029621 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:20] Energy consumed for RAM : 0.001227 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:23:20] Energy consumed for all CPUs : 0.010976 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:23:20] Energy consumed for all GPUs : 0.017903 kWh. Total GPU Power : 69.24003865921166 W
# [codecarbon INFO @ 09:23:20] 0.030106 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:35] Energy consumed for RAM : 0.001247 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:23:35] Energy consumed for all CPUs : 0.011153 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:23:35] Energy consumed for all GPUs : 0.018194 kWh. Total GPU Power : 69.82034469074735 W
# [codecarbon INFO @ 09:23:35] 0.030594 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:50] Energy consumed for RAM : 0.001267 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:23:50] Energy consumed for all CPUs : 0.011330 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:23:50] Energy consumed for all GPUs : 0.018483 kWh. Total GPU Power : 69.29659365393638 W
# [codecarbon INFO @ 09:23:50] 0.031080 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:50] 0.008671 g.CO2eq/s mean an estimation of 273.4405513648588 kg.CO2eq/year
# [codecarbon INFO @ 09:24:05] Energy consumed for RAM : 0.001287 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:24:05] Energy consumed for all CPUs : 0.011507 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:24:05] Energy consumed for all GPUs : 0.018771 kWh. Total GPU Power : 69.27560117908911 W
# [codecarbon INFO @ 09:24:05] 0.031565 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:24:20] Energy consumed for RAM : 0.001306 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:24:20] Energy consumed for all CPUs : 0.011684 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:24:20] Energy consumed for all GPUs : 0.019062 kWh. Total GPU Power : 69.77719227924564 W
# [codecarbon INFO @ 09:24:20] 0.032052 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:24:35] Energy consumed for RAM : 0.001326 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:24:35] Energy consumed for all CPUs : 0.011861 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:24:35] Energy consumed for all GPUs : 0.019351 kWh. Total GPU Power : 69.3389594357789 W
# [codecarbon INFO @ 09:24:35] 0.032538 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:24:50] Energy consumed for RAM : 0.001346 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:24:50] Energy consumed for all CPUs : 0.012038 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:24:50] Energy consumed for all GPUs : 0.019639 kWh. Total GPU Power : 69.18967429463369 W
# [codecarbon INFO @ 09:24:50] 0.033023 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:05] Energy consumed for RAM : 0.001366 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:25:05] Energy consumed for all CPUs : 0.012215 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:25:05] Energy consumed for all GPUs : 0.019930 kWh. Total GPU Power : 69.80552643754648 W
# [codecarbon INFO @ 09:25:05] 0.033511 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:20] Energy consumed for RAM : 0.001386 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:25:20] Energy consumed for all CPUs : 0.012392 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:25:20] Energy consumed for all GPUs : 0.020218 kWh. Total GPU Power : 69.1841304364687 W
# [codecarbon INFO @ 09:25:20] 0.033996 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:35] Energy consumed for RAM : 0.001405 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:25:35] Energy consumed for all CPUs : 0.012569 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:25:35] Energy consumed for all GPUs : 0.020509 kWh. Total GPU Power : 69.91057714386666 W
# [codecarbon INFO @ 09:25:35] 0.034484 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:50] Energy consumed for RAM : 0.001425 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:25:50] Energy consumed for all CPUs : 0.012746 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:25:50] Energy consumed for all GPUs : 0.020801 kWh. Total GPU Power : 69.83831829000897 W
# [codecarbon INFO @ 09:25:50] 0.034972 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:50] 0.008678 g.CO2eq/s mean an estimation of 273.66200925857737 kg.CO2eq/year
# [codecarbon INFO @ 09:26:05] Energy consumed for RAM : 0.001445 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:26:05] Energy consumed for all CPUs : 0.012923 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:26:05] Energy consumed for all GPUs : 0.021090 kWh. Total GPU Power : 69.34684057858514 W
# [codecarbon INFO @ 09:26:05] 0.035458 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:26:20] Energy consumed for RAM : 0.001465 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:26:20] Energy consumed for all CPUs : 0.013100 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:26:20] Energy consumed for all GPUs : 0.021381 kWh. Total GPU Power : 69.9073989734368 W
# [codecarbon INFO @ 09:26:20] 0.035946 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:26:35] Energy consumed for RAM : 0.001485 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:26:35] Energy consumed for all CPUs : 0.013277 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:26:35] Energy consumed for all GPUs : 0.021672 kWh. Total GPU Power : 69.98614753240618 W
# [codecarbon INFO @ 09:26:35] 0.036434 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:26:50] Energy consumed for RAM : 0.001504 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:26:50] Energy consumed for all CPUs : 0.013454 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:26:50] Energy consumed for all GPUs : 0.021962 kWh. Total GPU Power : 69.485756837276 W
# [codecarbon INFO @ 09:26:50] 0.036921 kWh of electricity used since the beginning.
# You are using a model of type modernbert to instantiate a model of type distilbert. This is not supported for all configurations of models and can yield errors.
# [codecarbon INFO @ 09:27:05] Energy consumed for RAM : 0.001524 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:27:05] Energy consumed for all CPUs : 0.013631 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:27:05] Energy consumed for all GPUs : 0.022249 kWh. Total GPU Power : 68.95068109492038 W
# [codecarbon INFO @ 09:27:05] 0.037405 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:20] Energy consumed for RAM : 0.001544 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:27:20] Energy consumed for all CPUs : 0.013808 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:27:20] Energy consumed for all GPUs : 0.022538 kWh. Total GPU Power : 69.18785134892089 W
# [codecarbon INFO @ 09:27:20] 0.037890 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:35] Energy consumed for RAM : 0.001564 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:27:35] Energy consumed for all CPUs : 0.013985 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:27:35] Energy consumed for all GPUs : 0.022828 kWh. Total GPU Power : 69.70818941649199 W
# [codecarbon INFO @ 09:27:35] 0.038377 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:50] Energy consumed for RAM : 0.001584 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:27:50] Energy consumed for all CPUs : 0.014162 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:27:50] Energy consumed for all GPUs : 0.023117 kWh. Total GPU Power : 69.36493238672533 W
# [codecarbon INFO @ 09:27:50] 0.038863 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:50] 0.008672 g.CO2eq/s mean an estimation of 273.48958840214505 kg.CO2eq/year
# [codecarbon INFO @ 09:28:05] Energy consumed for RAM : 0.001603 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:28:05] Energy consumed for all CPUs : 0.014339 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:28:05] Energy consumed for all GPUs : 0.023405 kWh. Total GPU Power : 69.30277993770594 W
# [codecarbon INFO @ 09:28:05] 0.039348 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:28:20] Energy consumed for RAM : 0.001623 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:28:20] Energy consumed for all CPUs : 0.014516 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:28:20] Energy consumed for all GPUs : 0.023694 kWh. Total GPU Power : 69.35259924658052 W
# [codecarbon INFO @ 09:28:20] 0.039834 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:28:35] Energy consumed for RAM : 0.001643 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:28:35] Energy consumed for all CPUs : 0.014693 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:28:35] Energy consumed for all GPUs : 0.023984 kWh. Total GPU Power : 69.7005167029399 W
# [codecarbon INFO @ 09:28:35] 0.040321 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:28:50] Energy consumed for RAM : 0.001663 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:28:50] Energy consumed for all CPUs : 0.014870 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:28:50] Energy consumed for all GPUs : 0.024273 kWh. Total GPU Power : 69.35651587139024 W
# [codecarbon INFO @ 09:28:50] 0.040806 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:05] Energy consumed for RAM : 0.001682 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:29:05] Energy consumed for all CPUs : 0.015047 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:29:05] Energy consumed for all GPUs : 0.024562 kWh. Total GPU Power : 69.33276287587 W
# [codecarbon INFO @ 09:29:05] 0.041291 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:20] Energy consumed for RAM : 0.001702 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:29:20] Energy consumed for all CPUs : 0.015224 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:29:20] Energy consumed for all GPUs : 0.024853 kWh. Total GPU Power : 69.72232481988897 W
# [codecarbon INFO @ 09:29:20] 0.041779 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:35] Energy consumed for RAM : 0.001722 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:29:35] Energy consumed for all CPUs : 0.015401 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:29:35] Energy consumed for all GPUs : 0.025141 kWh. Total GPU Power : 69.38654256801277 W
# [codecarbon INFO @ 09:29:35] 0.042265 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:50] Energy consumed for RAM : 0.001742 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:29:50] Energy consumed for all CPUs : 0.015578 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:29:50] Energy consumed for all GPUs : 0.025432 kWh. Total GPU Power : 69.73132385765285 W
# [codecarbon INFO @ 09:29:50] 0.042752 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:50] 0.008673 g.CO2eq/s mean an estimation of 273.510446908216 kg.CO2eq/year
# [codecarbon INFO @ 09:30:05] Energy consumed for RAM : 0.001762 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:30:05] Energy consumed for all CPUs : 0.015755 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:30:05] Energy consumed for all GPUs : 0.025720 kWh. Total GPU Power : 69.17386519768354 W
# [codecarbon INFO @ 09:30:05] 0.043237 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:30:20] Energy consumed for RAM : 0.001781 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:30:20] Energy consumed for all CPUs : 0.015932 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:30:20] Energy consumed for all GPUs : 0.026009 kWh. Total GPU Power : 69.21994994696334 W
# [codecarbon INFO @ 09:30:20] 0.043723 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:30:35] Energy consumed for RAM : 0.001801 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:30:35] Energy consumed for all CPUs : 0.016110 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:30:35] Energy consumed for all GPUs : 0.026299 kWh. Total GPU Power : 69.76231504964407 W
# [codecarbon INFO @ 09:30:35] 0.044210 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:30:50] Energy consumed for RAM : 0.001821 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:30:50] Energy consumed for all CPUs : 0.016286 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:30:50] Energy consumed for all GPUs : 0.026588 kWh. Total GPU Power : 69.3697460310709 W
# [codecarbon INFO @ 09:30:50] 0.044696 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:05] Energy consumed for RAM : 0.001841 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:31:05] Energy consumed for all CPUs : 0.016463 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:31:05] Energy consumed for all GPUs : 0.026879 kWh. Total GPU Power : 69.7963238300819 W
# [codecarbon INFO @ 09:31:05] 0.045183 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:20] Energy consumed for RAM : 0.001861 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:31:20] Energy consumed for all CPUs : 0.016640 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:31:20] Energy consumed for all GPUs : 0.027168 kWh. Total GPU Power : 69.3827389781796 W
# [codecarbon INFO @ 09:31:20] 0.045669 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:35] Energy consumed for RAM : 0.001880 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:31:35] Energy consumed for all CPUs : 0.016817 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:31:35] Energy consumed for all GPUs : 0.027456 kWh. Total GPU Power : 69.24883792347528 W
# [codecarbon INFO @ 09:31:35] 0.046154 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:50] Energy consumed for RAM : 0.001900 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:31:50] Energy consumed for all CPUs : 0.016994 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:31:50] Energy consumed for all GPUs : 0.027745 kWh. Total GPU Power : 69.30049092058631 W
# [codecarbon INFO @ 09:31:50] 0.046640 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:50] 0.008666 g.CO2eq/s mean an estimation of 273.2977167912377 kg.CO2eq/year
# [codecarbon INFO @ 09:32:05] Energy consumed for RAM : 0.001920 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:32:05] Energy consumed for all CPUs : 0.017172 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:32:05] Energy consumed for all GPUs : 0.028035 kWh. Total GPU Power : 69.62060160818129 W
# [codecarbon INFO @ 09:32:05] 0.047127 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:32:20] Energy consumed for RAM : 0.001940 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:32:20] Energy consumed for all CPUs : 0.017348 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:32:20] Energy consumed for all GPUs : 0.028324 kWh. Total GPU Power : 69.24095711850794 W
# [codecarbon INFO @ 09:32:20] 0.047612 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:32:35] Energy consumed for RAM : 0.001960 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:32:35] Energy consumed for all CPUs : 0.017525 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:32:35] Energy consumed for all GPUs : 0.028612 kWh. Total GPU Power : 69.3170310915111 W
# [codecarbon INFO @ 09:32:35] 0.048097 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:32:50] Energy consumed for RAM : 0.001979 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:32:50] Energy consumed for all CPUs : 0.017703 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:32:50] Energy consumed for all GPUs : 0.028903 kWh. Total GPU Power : 69.70553976802033 W
# [codecarbon INFO @ 09:32:50] 0.048585 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:05] Energy consumed for RAM : 0.001999 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:33:05] Energy consumed for all CPUs : 0.017879 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:33:05] Energy consumed for all GPUs : 0.029191 kWh. Total GPU Power : 69.36574837760168 W
# [codecarbon INFO @ 09:33:05] 0.049070 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:20] Energy consumed for RAM : 0.002019 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:33:20] Energy consumed for all CPUs : 0.018056 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:33:20] Energy consumed for all GPUs : 0.029482 kWh. Total GPU Power : 69.64643922237246 W
# [codecarbon INFO @ 09:33:20] 0.049557 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:35] Energy consumed for RAM : 0.002039 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:33:35] Energy consumed for all CPUs : 0.018234 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:33:35] Energy consumed for all GPUs : 0.029770 kWh. Total GPU Power : 69.26520746577297 W
# [codecarbon INFO @ 09:33:35] 0.050043 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:50] Energy consumed for RAM : 0.002059 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:33:50] Energy consumed for all CPUs : 0.018411 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:33:50] Energy consumed for all GPUs : 0.030061 kWh. Total GPU Power : 69.6570145632379 W
# [codecarbon INFO @ 09:33:50] 0.050530 kWh of electricity used since the beginning.
# ...
# [codecarbon INFO @ 09:56:20] Energy consumed for all CPUs : 0.034343 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:56:20] Energy consumed for all GPUs : 0.056107 kWh. Total GPU Power : 69.27845775747136 W
# [codecarbon INFO @ 09:56:20] 0.094290 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:56:35] Energy consumed for RAM : 0.003860 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:56:35] Energy consumed for all CPUs : 0.034520 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:56:35] Energy consumed for all GPUs : 0.056397 kWh. Total GPU Power : 69.71996325308497 W
# [codecarbon INFO @ 09:56:35] 0.094777 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:56:50] Energy consumed for RAM : 0.003879 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:56:50] Energy consumed for all CPUs : 0.034697 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:56:50] Energy consumed for all GPUs : 0.056686 kWh. Total GPU Power : 69.38295935588373 W
# [codecarbon INFO @ 09:56:50] 0.095263 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:57:05] Energy consumed for RAM : 0.003899 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:57:05] Energy consumed for all CPUs : 0.034874 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:57:05] Energy consumed for all GPUs : 0.056977 kWh. Total GPU Power : 69.74801036404473 W
# [codecarbon INFO @ 09:57:05] 0.095750 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:57:20] Energy consumed for RAM : 0.003919 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:57:20] Energy consumed for all CPUs : 0.035051 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:57:20] Energy consumed for all GPUs : 0.057266 kWh. Total GPU Power : 69.33513055977328 W
# [codecarbon INFO @ 09:57:20] 0.096236 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:57:35] Energy consumed for RAM : 0.003939 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:57:35] Energy consumed for all CPUs : 0.035228 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:57:35] Energy consumed for all GPUs : 0.057554 kWh. Total GPU Power : 69.24676046471768 W
# [codecarbon INFO @ 09:57:35] 0.096721 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:57:50] Energy consumed for RAM : 0.003959 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:57:50] Energy consumed for all CPUs : 0.035405 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:57:50] Energy consumed for all GPUs : 0.057845 kWh. Total GPU Power : 69.75665469885641 W
# [codecarbon INFO @ 09:57:50] 0.097208 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:57:50] 0.008672 g.CO2eq/s mean an estimation of 273.4676744603958 kg.CO2eq/year
# [codecarbon INFO @ 09:58:05] Energy consumed for RAM : 0.003978 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:58:05] Energy consumed for all CPUs : 0.035582 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:58:05] Energy consumed for all GPUs : 0.058133 kWh. Total GPU Power : 69.38105304528989 W
# [codecarbon INFO @ 09:58:05] 0.097694 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:58:20] Energy consumed for RAM : 0.003998 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:58:20] Energy consumed for all CPUs : 0.035759 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:58:20] Energy consumed for all GPUs : 0.058423 kWh. Total GPU Power : 69.43739148452755 W
# [codecarbon INFO @ 09:58:20] 0.098180 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:58:35] Energy consumed for RAM : 0.004018 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:58:35] Energy consumed for all CPUs : 0.035936 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:58:35] Energy consumed for all GPUs : 0.058713 kWh. Total GPU Power : 69.66467016699687 W
# [codecarbon INFO @ 09:58:35] 0.098667 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:58:50] Energy consumed for RAM : 0.004038 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:58:50] Energy consumed for all CPUs : 0.036113 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:58:50] Energy consumed for all GPUs : 0.059002 kWh. Total GPU Power : 69.31667842132084 W
# [codecarbon INFO @ 09:58:50] 0.099153 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:59:05] Energy consumed for RAM : 0.004058 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:59:05] Energy consumed for all CPUs : 0.036290 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:59:05] Energy consumed for all GPUs : 0.059290 kWh. Total GPU Power : 69.32182795999543 W
# [codecarbon INFO @ 09:59:05] 0.099637 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:59:20] Energy consumed for RAM : 0.004077 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:59:20] Energy consumed for all CPUs : 0.036467 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:59:20] Energy consumed for all GPUs : 0.059581 kWh. Total GPU Power : 69.79164392304699 W
# [codecarbon INFO @ 09:59:20] 0.100125 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:59:35] Energy consumed for RAM : 0.004097 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:59:35] Energy consumed for all CPUs : 0.036644 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:59:35] Energy consumed for all GPUs : 0.059869 kWh. Total GPU Power : 69.23536592140404 W
# [codecarbon INFO @ 09:59:35] 0.100610 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:59:50] Energy consumed for RAM : 0.004117 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 09:59:50] Energy consumed for all CPUs : 0.036821 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 09:59:50] Energy consumed for all GPUs : 0.060158 kWh. Total GPU Power : 69.29943954823597 W
# [codecarbon INFO @ 09:59:50] 0.101096 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:59:50] 0.008668 g.CO2eq/s mean an estimation of 273.34942461952426 kg.CO2eq/year
# [codecarbon INFO @ 10:00:05] Energy consumed for RAM : 0.004137 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:00:05] Energy consumed for all CPUs : 0.036998 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:00:05] Energy consumed for all GPUs : 0.060448 kWh. Total GPU Power : 69.68314430592328 W
# [codecarbon INFO @ 10:00:05] 0.101583 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:00:20] Energy consumed for RAM : 0.004157 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:00:20] Energy consumed for all CPUs : 0.037175 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:00:20] Energy consumed for all GPUs : 0.060737 kWh. Total GPU Power : 69.26480557404615 W
# [codecarbon INFO @ 10:00:20] 0.102068 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:00:35] Energy consumed for RAM : 0.004176 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:00:35] Energy consumed for all CPUs : 0.037352 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:00:35] Energy consumed for all GPUs : 0.061026 kWh. Total GPU Power : 69.37063506177915 W
# [codecarbon INFO @ 10:00:35] 0.102554 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:00:50] Energy consumed for RAM : 0.004196 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:00:50] Energy consumed for all CPUs : 0.037529 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:00:50] Energy consumed for all GPUs : 0.061317 kWh. Total GPU Power : 69.80053571904456 W
# [codecarbon INFO @ 10:00:50] 0.103042 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:01:05] Energy consumed for RAM : 0.004216 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:01:05] Energy consumed for all CPUs : 0.037706 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:01:05] Energy consumed for all GPUs : 0.061605 kWh. Total GPU Power : 69.28537915511927 W
# [codecarbon INFO @ 10:01:05] 0.103527 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:01:20] Energy consumed for RAM : 0.004236 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:01:20] Energy consumed for all CPUs : 0.037883 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:01:20] Energy consumed for all GPUs : 0.061896 kWh. Total GPU Power : 69.78891795340273 W
# [codecarbon INFO @ 10:01:20] 0.104014 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:01:35] Energy consumed for RAM : 0.004255 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:01:35] Energy consumed for all CPUs : 0.038060 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:01:36] Energy consumed for all GPUs : 0.062185 kWh. Total GPU Power : 69.25491504037171 W
# [codecarbon INFO @ 10:01:36] 0.104500 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:01:50] Energy consumed for RAM : 0.004275 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:01:50] Energy consumed for all CPUs : 0.038237 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:01:51] Energy consumed for all GPUs : 0.062473 kWh. Total GPU Power : 69.39310900635196 W
# [codecarbon INFO @ 10:01:51] 0.104986 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:01:51] 0.008671 g.CO2eq/s mean an estimation of 273.45518322287825 kg.CO2eq/year
# [codecarbon INFO @ 10:02:05] Energy consumed for RAM : 0.004295 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:02:05] Energy consumed for all CPUs : 0.038414 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:02:06] Energy consumed for all GPUs : 0.062762 kWh. Total GPU Power : 69.20384956355593 W
# [codecarbon INFO @ 10:02:06] 0.105470 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:02:20] Energy consumed for RAM : 0.004315 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:02:20] Energy consumed for all CPUs : 0.038591 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:02:21] Energy consumed for all GPUs : 0.063052 kWh. Total GPU Power : 69.83799915182202 W
# [codecarbon INFO @ 10:02:21] 0.105958 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:02:35] Energy consumed for RAM : 0.004335 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:02:36] Energy consumed for all CPUs : 0.038768 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:02:36] Energy consumed for all GPUs : 0.063341 kWh. Total GPU Power : 69.33858671541225 W
# [codecarbon INFO @ 10:02:36] 0.106443 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:02:51] Energy consumed for RAM : 0.004354 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:02:51] Energy consumed for all CPUs : 0.038945 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:02:51] Energy consumed for all GPUs : 0.063632 kWh. Total GPU Power : 69.85716933437023 W
# [codecarbon INFO @ 10:02:51] 0.106931 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:03:06] Energy consumed for RAM : 0.004374 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:03:06] Energy consumed for all CPUs : 0.039122 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:03:06] Energy consumed for all GPUs : 0.063921 kWh. Total GPU Power : 69.3468618880817 W
# [codecarbon INFO @ 10:03:06] 0.107417 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:03:21] Energy consumed for RAM : 0.004394 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:03:21] Energy consumed for all CPUs : 0.039299 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:03:21] Energy consumed for all GPUs : 0.064209 kWh. Total GPU Power : 69.20933261954663 W
# [codecarbon INFO @ 10:03:21] 0.107902 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:03:36] Energy consumed for RAM : 0.004414 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:03:36] Energy consumed for all CPUs : 0.039476 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:03:36] Energy consumed for all GPUs : 0.064500 kWh. Total GPU Power : 69.84382146823252 W
# [codecarbon INFO @ 10:03:36] 0.108390 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:03:51] Energy consumed for RAM : 0.004434 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:03:51] Energy consumed for all CPUs : 0.039653 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:03:51] Energy consumed for all GPUs : 0.064790 kWh. Total GPU Power : 69.4687329446986 W
# [codecarbon INFO @ 10:03:51] 0.108876 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:03:51] 0.008674 g.CO2eq/s mean an estimation of 273.55421640603896 kg.CO2eq/year
# [codecarbon INFO @ 10:04:06] Energy consumed for RAM : 0.004453 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:04:06] Energy consumed for all CPUs : 0.039830 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:04:06] Energy consumed for all GPUs : 0.065081 kWh. Total GPU Power : 70.00325893919484 W
# [codecarbon INFO @ 10:04:06] 0.109365 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:04:21] Energy consumed for RAM : 0.004473 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:04:21] Energy consumed for all CPUs : 0.040007 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:04:21] Energy consumed for all GPUs : 0.065371 kWh. Total GPU Power : 69.4645997406738 W
# [codecarbon INFO @ 10:04:21] 0.109851 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:04:36] Energy consumed for RAM : 0.004493 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:04:36] Energy consumed for all CPUs : 0.040184 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:04:36] Energy consumed for all GPUs : 0.065662 kWh. Total GPU Power : 69.8107144314925 W
# [codecarbon INFO @ 10:04:36] 0.110338 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:04:51] Energy consumed for RAM : 0.004513 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:04:51] Energy consumed for all CPUs : 0.040361 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:04:51] Energy consumed for all GPUs : 0.065953 kWh. Total GPU Power : 69.8312610412798 W
# [codecarbon INFO @ 10:04:51] 0.110827 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:05:06] Energy consumed for RAM : 0.004533 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:05:06] Energy consumed for all CPUs : 0.040538 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:05:06] Energy consumed for all GPUs : 0.066242 kWh. Total GPU Power : 69.53235242816379 W
# [codecarbon INFO @ 10:05:06] 0.111313 kWh of electricity used since the beginning.
# [codecarbon INFO @ 10:05:21] Energy consumed for RAM : 0.004552 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:05:21] Energy consumed for all CPUs : 0.040715 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:05:21] Energy consumed for all GPUs : 0.066533 kWh. Total GPU Power : 69.93199469667141 W
# [codecarbon INFO @ 10:05:21] 0.111801 kWh of electricity used since the beginning.
# You are using a model of type modernbert to instantiate a model of type distilbert. This is not supported for all configurations of models and can yield errors.
# [codecarbon INFO @ 10:05:23] Energy consumed for RAM : 0.004556 kWh. RAM Power : 4.753036022186279 W
# [codecarbon INFO @ 10:05:23] Energy consumed for all CPUs : 0.040745 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 10:05:23] Energy consumed for all GPUs : 0.066580 kWh. Total GPU Power : 65.09855475131353 W
# [codecarbon INFO @ 10:05:23] 0.111881 kWh of electricity used since the beginning.
# /usr/local/lib/python3.11/dist-packages/codecarbon/output_methods/file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])

# %% [markdown]
# **FINETUNING SANS LoRa**

# %%
#SANS LORA
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from transformers import Trainer, TrainingArguments
from codecarbon import EmissionsTracker
import torch

# Récupérer les noms des classes depuis le dataset
class_names = dataset['train'].features['label'].names

# Fonction pour calculer les métriques
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = torch.argmax(torch.tensor(logits), dim=-1)

    accuracy = accuracy_score(labels, predictions)
    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average=None, zero_division=1
    )

    precision_global = precision.mean()
    recall_global = recall.mean()
    f1_macro = f1.mean()

    metrics = {
        "accuracy": accuracy,
        "precision_global": precision_global,
        "recall_global": recall_global,
        "f1_macro": f1_macro
    }

    for i, (p, r, f) in enumerate(zip(precision, recall, f1)):
        metrics[f"precision_{class_names[i]}"] = p
        metrics[f"recall_{class_names[i]}"] = r
        metrics[f"f1_{class_names[i]}"] = f

    return metrics

# Configuration de l'entraînement (fine-tuning complet, sans LoRA)
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="steps",
    logging_steps=10,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    report_to="wandb",  # ou "none" si tu ne veux pas utiliser wandb
    overwrite_output_dir=True,
    disable_tqdm=False
)

# Datasets
small_train_dataset = tokenized_datasets["train"]
small_test_dataset = tokenized_datasets["test"]

# Création du Trainer avec le modèle de base (fine-tuning complet)
trainer = Trainer(
    model=base_model,  # Pas de modèle modifié par LoRA
    args=training_args,
    train_dataset=small_train_dataset,
    eval_dataset=small_test_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# Suivi des émissions
tracker = EmissionsTracker()
tracker.start()

# Entraînement
train_result = trainer.train()

# Fin du suivi
emissions = tracker.stop()

# %%
# !zip -r ModernBERT_hatespeech_lora.zip ./
# Out:
#   adding: .config/ (stored 0%)
#   adding: .config/active_config (stored 0%)
#   adding: .config/configurations/ (stored 0%)
#   adding: .config/configurations/config_default (deflated 15%)
#   adding: .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: .config/default_configs.db (deflated 98%)
#   adding: .config/.last_survey_prompt.yaml (stored 0%)
#   adding: .config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: .config/logs/ (stored 0%)
#   adding: .config/logs/2025.04.09/ (stored 0%)
#   adding: .config/logs/2025.04.09/13.38.09.438379.log (deflated 56%)
#   adding: .config/logs/2025.04.09/13.37.59.170421.log (deflated 86%)
#   adding: .config/logs/2025.04.09/13.38.00.354311.log (deflated 58%)
#   adding: .config/logs/2025.04.09/13.37.30.549742.log (deflated 93%)
#   adding: .config/logs/2025.04.09/13.38.08.751788.log (deflated 57%)
#   adding: .config/logs/2025.04.09/13.37.51.026068.log (deflated 58%)
#   adding: .config/config_sentinel (stored 0%)
#   adding: .config/.last_update_check.json (deflated 22%)
#   adding: .config/gce (stored 0%)
#   adding: emissions.csv (deflated 36%)
#   adding: wandb/ (stored 0%)
#   adding: wandb/debug.log (deflated 67%)
#   adding: wandb/run-20250411_090631-982zkfhf/ (stored 0%)
#   adding: wandb/run-20250411_090631-982zkfhf/files/ (stored 0%)
#   adding: wandb/run-20250411_090631-982zkfhf/files/wandb-metadata.json (deflated 43%)
#   adding: wandb/run-20250411_090631-982zkfhf/files/requirements.txt (deflated 55%)
#   adding: wandb/run-20250411_090631-982zkfhf/files/output.log (stored 0%)
#   adding: wandb/run-20250411_090631-982zkfhf/logs/ (stored 0%)
#   adding: wandb/run-20250411_090631-982zkfhf/logs/debug.log (deflated 67%)
#   adding: wandb/run-20250411_090631-982zkfhf/logs/debug-core.log (deflated 58%)
#   adding: wandb/run-20250411_090631-982zkfhf/logs/debug-internal.log (deflated 65%)
#   adding: wandb/run-20250411_090631-982zkfhf/tmp/ (stored 0%)
#   adding: wandb/run-20250411_090631-982zkfhf/tmp/code/ (stored 0%)
#   adding: wandb/run-20250411_090631-982zkfhf/run-982zkfhf.wandb (stored 0%)
#   adding: wandb/debug-internal.log (deflated 68%)
#   adding: wandb/run-20250411_090750-k7a5s78m/ (stored 0%)
#   adding: wandb/run-20250411_090750-k7a5s78m/files/ (stored 0%)
#   adding: wandb/run-20250411_090750-k7a5s78m/files/wandb-metadata.json (deflated 43%)
#   adding: wandb/run-20250411_090750-k7a5s78m/files/requirements.txt (deflated 55%)
#   adding: wandb/run-20250411_090750-k7a5s78m/files/output.log (deflated 89%)
#   adding: wandb/run-20250411_090750-k7a5s78m/run-k7a5s78m.wandb (deflated 81%)
#   adding: wandb/run-20250411_090750-k7a5s78m/logs/ (stored 0%)
#   adding: wandb/run-20250411_090750-k7a5s78m/logs/debug.log (deflated 67%)
#   adding: wandb/run-20250411_090750-k7a5s78m/logs/debug-core.log (deflated 57%)
#   adding: wandb/run-20250411_090750-k7a5s78m/logs/debug-internal.log (deflated 68%)
#   adding: wandb/run-20250411_090750-k7a5s78m/tmp/ (stored 0%)
#   adding: wandb/run-20250411_090750-k7a5s78m/tmp/code/ (stored 0%)
#   adding: wandb/latest-run/ (stored 0%)
#   adding: wandb/latest-run/files/ (stored 0%)
#   adding: wandb/latest-run/files/wandb-metadata.json (deflated 43%)
#   adding: wandb/latest-run/files/requirements.txt (deflated 55%)
#   adding: wandb/latest-run/files/output.log (deflated 89%)
#   adding: wandb/latest-run/run-k7a5s78m.wandb (deflated 81%)
#   adding: wandb/latest-run/logs/ (stored 0%)
#   adding: wandb/latest-run/logs/debug.log (deflated 67%)
#   adding: wandb/latest-run/logs/debug-core.log (deflated 57%)
#   adding: wandb/latest-run/logs/debug-internal.log (deflated 68%)
#   adding: wandb/latest-run/tmp/ (stored 0%)
#   adding: wandb/latest-run/tmp/code/ (stored 0%)
#   adding: results/ (stored 0%)
#   adding: results/checkpoint-3285/ (stored 0%)
#   adding: results/checkpoint-3285/scheduler.pt (deflated 56%)
#   adding: results/checkpoint-3285/adapter_model.safetensors (deflated 7%)
#   adding: results/checkpoint-3285/README.md (deflated 66%)
#   adding: results/checkpoint-3285/tokenizer.json (deflated 82%)
#   adding: results/checkpoint-3285/trainer_state.json (deflated 82%)
#   adding: results/checkpoint-3285/rng_state.pth (deflated 25%)
#   adding: results/checkpoint-3285/tokenizer_config.json (deflated 95%)
#   adding: results/checkpoint-3285/optimizer.pt (deflated 8%)
#   adding: results/checkpoint-3285/training_args.bin (deflated 51%)
#   adding: results/checkpoint-3285/special_tokens_map.json (deflated 79%)
#   adding: results/checkpoint-3285/adapter_config.json (deflated 54%)
#   adding: results/checkpoint-2190/ (stored 0%)
#   adding: results/checkpoint-2190/scheduler.pt (deflated 55%)
#   adding: results/checkpoint-2190/adapter_model.safetensors (deflated 7%)
#   adding: results/checkpoint-2190/README.md (deflated 66%)
#   adding: results/checkpoint-2190/tokenizer.json (deflated 82%)
#   adding: results/checkpoint-2190/trainer_state.json (deflated 81%)
#   adding: results/checkpoint-2190/rng_state.pth (deflated 25%)
#   adding: results/checkpoint-2190/tokenizer_config.json (deflated 95%)
#   adding: results/checkpoint-2190/optimizer.pt (deflated 8%)
#   adding: results/checkpoint-2190/training_args.bin (deflated 51%)
#   adding: results/checkpoint-2190/special_tokens_map.json (deflated 79%)
#   adding: results/checkpoint-2190/adapter_config.json (deflated 54%)
#   adding: results/checkpoint-1095/ (stored 0%)
#   adding: results/checkpoint-1095/scheduler.pt (deflated 55%)
#   adding: results/checkpoint-1095/adapter_model.safetensors (deflated 7%)
#   adding: results/checkpoint-1095/README.md (deflated 66%)
#   adding: results/checkpoint-1095/tokenizer.json (deflated 82%)
#   adding: results/checkpoint-1095/trainer_state.json (deflated 80%)
#   adding: results/checkpoint-1095/rng_state.pth (deflated 25%)
#   adding: results/checkpoint-1095/tokenizer_config.json (deflated 95%)
#   adding: results/checkpoint-1095/optimizer.pt (deflated 7%)
#   adding: results/checkpoint-1095/training_args.bin (deflated 51%)
#   adding: results/checkpoint-1095/special_tokens_map.json (deflated 79%)
#   adding: results/checkpoint-1095/adapter_config.json (deflated 54%)
#   adding: sample_data/ (stored 0%)
#   adding: sample_data/README.md (deflated 39%)
#   adding: sample_data/anscombe.json (deflated 83%)
#   adding: sample_data/california_housing_test.csv (deflated 76%)
#   adding: sample_data/mnist_test.csv (deflated 88%)
#   adding: sample_data/california_housing_train.csv (deflated 79%)
#   adding: sample_data/mnist_train_small.csv (deflated 88%)
